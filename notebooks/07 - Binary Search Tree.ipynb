# %% [markdown]
# # 07 - Binary Search Tree (BST)
#
# Estruturas de Dados e Algoritmos
#
# Ciência da Computação
#
# Universidade Federal de Campina Grande (UFCG)
#
# Rafael de Arruda Sobral (UFCG/SEE-PB)
#
# Prof. Dr. Adalberto Cajueiro de Farias (UFCG)

# %% [markdown]
# - Crie uma cópia deste *Notebook* do *Google Colaboratory* em seu *Google Drive*: `Arquivo` -> `Salvar uma cópia no Drive`.
#
# - Vale ressaltar que este material é um complemento ao conteúdo estudado no componente curricular "Estruturas de Dados e Algoritmos" do curso de Ciência da Computação da UFCG, com o intuito de contribuir com as aulas de monitoria.

# %% [markdown]
# Este material aborda a estrutura de dados hierárquica conhecida como Binary Search Tree (BST), além de propor alguns exercícios práticos.

# %% [markdown]
# # Teoria dos Grafos e Árvores

# %% [markdown]
# Binary Search Tree (BST) pode ser traduzida como Árvore Binária de Busca, ou ainda Árvore Binária de Pesquisa. Você deve lembrar de quando estudou esse tipo de estrutura de dados em Teoria dos Grafos, certo? As árvores podem ser compreendidas como grafos acíclicos e conectados, sendo aplicados amplamente em vários problemas e requisitos da Ciência da Computação, tal como em árvores sintáticas, analisadores sintáticos, diagramas de fluxo de execução, dentre outras aplicações que também dialogam com abordagens usadas pela Inteligência Artificial (Buscas Heurísticas, por exemplo).
#
# Para tanto, é válido lembrar de alguns conceitos e propriedades que podem ajudar a otimizar a compreensão sobre essa estrutura valiosa. Considere os teoremas a seguir:
#
# - Teorema 1: Em uma árvore, quaisquer dois vértices são conectados por exatamente um caminho. Observe que a ideia de caminhamento em árvores existe através da compreensão de que é possível "passear" pelo grafo por meio das arestas que conectam os vértices, isto é, os nós que compõem a árvore. Logo, faz sentido existir um caminho entre o nó raiz, o(s) nó(s) filho(s) e/ou o(s) nó(s) folha(s). Vale ressaltar que não existem ciclos nesse caminhamento.
#
# - Teorema 2: Se T é uma árvore, então e(T) = v(T) - 1. Considere e(T) uma referência para a cardinalidade das arestas, enquanto v(T) é a cardinalidade dos vértices. Nesse sentido, perceba que o número de arestas é equivalente a subtrair uma unidade do número de vértices.
#
# Tendo em vista esses teoremas, analise os grafos a seguir e reflita sobre como essas propriedades contribuem para nosso estudo com Binary Search Trees.
#
# ![picture](https://miro.medium.com/v2/resize:fit:1400/1*Jz6OQkYJrmm9-2JnfVx6cw.png)

# %% [markdown]
# Não obstante, é importante relembrar que, quando utilizamos árvores para
# representar relações hierárquicas ou ordenadas, eventualmente vamos determinar um vértice inicial, sendo o nosso vértice-raiz. Consequentemente, uma orientação é definida. Seguindo a imagem da árvore acima, vamos considerar o vértice 1 como a raiz.
#
#
# A partir dessas considerações, também podemos revisar algumas especialidades essenciais para nosso estudo com Binary Search Trees, a saber:
#
# - i) o nível de um vértice é o tamanho do caminho a partir da raiz (na árvore da imagem acima, os vértices 3 e 6 têm nível 1, enquanto os vértices 2, 4 e 5 têm nível 2);
#
# - ii) todo vértice x no caminho é chamado de ancestral e todo vértice y do qual x é ancestral é chamado de descendente (no nosso exemplo, os vértices 1 e 6 são ancestrais de 4, sendo este último o descendente);
#
# - iii) o ancestral imediato é chamado de predecessor ou pai, e os vértices para os quais ele é pai são chamados de sucessores ou filhos (em nossa imagem, o vértice 6 é pai de 2 e 4, sendo estes os seus filhos).
#
# A Teoria dos Grafos é demasiada extensa e enfatiza propriedades diferentes em árvores enquanto grafos, sendo esses conceitos apenas algumas das propriedades que fazem parte de nosso estudo de Binary Search Trees. Entretanto, aqui o foco é outro, tendo em vista que uma BST possui características específicas que a difere de outros tipos de árvores. A seguir, vamos considerar que você estudou o material da disciplina de Estruturas de Dados e Algoritmos, de maneira que este material apenas complemente os seus estudos.

# %% [markdown]
# # Binary Search Tree

# %% [markdown]
# Binary Search Trees (BST) são estruturas de dados hierárquicas derivadas de Binary Trees (BT). Elas são bastante eficientes em solucionar problemas que envolvem operações de inserção, remoção e busca de dados, por exemplo, dentre outras situações. De forma geral, as seguintes propriedades devem ser verdadeiras para qualquer nó que compõe a árvore:
#
# - i) seja x a raiz da árvore, então o nó a esquerda de x e todos os seus descendentes (filhos, filhos dos filhos e assim por diante) têm valores menores que o valor de x;
#
# - ii) seja x a raiz da árvore, o filho a direita de x e todos os seus descendentes têm valores maiores que o valor de x;
#
# - iii) as subárvores a esquerda e a direita também devem seguir o invariante de uma BST, tal como explicado em i e ii.
#
# Outras características também potencializam essa estrutura em termos de análise assintótica:
#
# - iv) o tamanho de uma árvore é o seu número de nós.
#
# - v) os descendentes de um nó são todos os nós filhos daquele nó e, consequentemente, todos os seus filhos.
#
# - vi) a altura de um nó é o número máximo de arestas entre aquele nó e um nó folha (que não possui filhos).
#
# Sugerimos que você também utilize a ferramenta a seguir para visualizar o comportamento dessa estrutura: [VisuAlgo](https://visualgo.net/en/bst). Aproveite para conferir outros exemplos de visualizações para as outras EDs que já estudamos anteriormente. Por fim, que tal uma imagem que resume uma série de propriedades das BSTs? Vamos lá:
#
# ![picture](https://miro.medium.com/v2/resize:fit:1194/0*OJaD7DmFOVdgFfiZ.png)
#
# E antes de finalizar, segue uma dica de jogo interativo que usa a lógica sobrejacente de uma BST para descobrir valores aleatórios em um intervalo de números inteiros: [Interactive Binary Search Tree](https://maththebeautiful.com/binary-search/). Divirta-se. Segue abaixo também o código em Python de uma BST. Tentamos seguir o mesmo design recursivo dos roteiros práticos de Laboratório de Estruturas de Dados e Algoritmos, então indicamos a você brincar um pouco e a fazer testes diferentes.

# %%
# @title {run: "auto"}

class BSTNode:

    def __init__(self, data=None, parent=None):
        self.data = data
        self.left = None
        self.right = None
        self.parent = parent

    def is_empty(self):
        return self.data is None

    def is_leaf(self):
        return not self.is_empty() and self.left.is_empty() and self.right.is_empty()

    def __repr__(self):
        return f"BSTNode({self.data})" if self.data is not None else "Empty"

class BST:

    def __init__(self):
        self.root = BSTNode()

    def is_empty(self):
        return self.root.is_empty()

    def height(self, node=None):
        if node is None:
            node = self.root
        if node.is_empty():
            return -1
        return 1 + max(self.height(node.left), self.height(node.right))

    def search(self, element, node=None):
        if element is None:
            return BSTNode()
        if node is None:
            node = self.root
        if node.is_empty() or node.data == element:
            return node
        elif element < node.data:
            return self.search(element, node.left)
        else:
            return self.search(element, node.right)

    def insert(self, element, node=None, parent=None):
        if element is None:
            return
        if node is None:
            node = self.root
        if node.is_empty():
            node.data = element
            node.left = BSTNode(parent=node)
            node.right = BSTNode(parent=node)
            node.parent = parent
        elif element < node.data:
            self.insert(element, node.left, node)
        elif element > node.data:
            self.insert(element, node.right, node)

    def maximum(self, node=None):
        if self.is_empty():
            return None
        if node is None:
            node = self.root
        while not node.right.is_empty():
            node = node.right
        return node

    def minimum(self, node=None):
        if self.is_empty():
            return None
        if node is None:
            node = self.root
        while not node.left.is_empty():
            node = node.left
        return node

    def successor(self, element):
        node = self.search(element)
        if node.is_empty():
            return None
        if not node.right.is_empty():
            return self.minimum(node.right)
        parent = node.parent
        while parent and parent.right == node:
            node = parent
            parent = parent.parent
        return parent

    def predecessor(self, element):
        node = self.search(element)
        if node.is_empty():
            return None
        if not node.left.is_empty():
            return self.maximum(node.left)
        parent = node.parent
        while parent and parent.left == node:
            node = parent
            parent = parent.parent
        return parent

    def remove(self, element):
        node = self.search(element)
        if node.is_empty():
            return
        if node.is_leaf():
            node.data = None
            node.left = None
            node.right = None
        elif node.left.is_empty() or node.right.is_empty():
            child = node.right if not node.right.is_empty() else node.left
            if node == self.root:
                self.root = child
                self.root.parent = None
            else:
                parent = node.parent
                if parent.left == node:
                    parent.left = child
                else:
                    parent.right = child
                child.parent = parent
        else:
            successor = self.successor(node.data)
            self.remove(successor.data)
            node.data = successor.data

    def size(self, node=None):
        if node is None:
            node = self.root
        if node.is_empty():
            return 0
        return 1 + self.size(node.left) + self.size(node.right)

    def pre_order(self, node=None, result=None):
        if result is None:
            result = []
        if node is None:
            node = self.root
        if not node.is_empty():
            result.append(node.data)
            self.pre_order(node.left, result)
            self.pre_order(node.right, result)
        return result

    def in_order(self, node=None, result=None):
        if result is None:
            result = []
        if node is None:
            node = self.root
        if not node.is_empty():
            self.in_order(node.left, result)
            result.append(node.data)
            self.in_order(node.right, result)
        return result

    def post_order(self, node=None, result=None):
        if result is None:
            result = []
        if node is None:
            node = self.root
        if not node.is_empty():
            self.post_order(node.left, result)
            self.post_order(node.right, result)
            result.append(node.data)
        return result

def test_bst():

    bst = BST()
    data = [10, 5, 15, 3, 7, 13, 17, 1, 4, 6]
    for value in data:
        bst.insert(value)

    print("1. In-Order Traversal:", bst.in_order())
    assert bst.in_order() == sorted(data)

    print("2. Pre-Order Traversal:", bst.pre_order())
    assert bst.pre_order() == [10, 5, 3, 1, 4, 7, 6, 15, 13, 17]

    print("3. Post-Order Traversal:", bst.post_order())
    assert bst.post_order() == [1, 4, 3, 6, 7, 5, 13, 17, 15, 10]

    print("4. Height:", bst.height())
    assert bst.height() == 3

    print("5. Size:", bst.size())
    assert bst.size() == 10

    print("6. Search 13:", bst.search(13).data)
    assert bst.search(13).data == 13

    print("7. Minimum:", bst.minimum().data)
    assert bst.minimum().data == 1

    print("8. Maximum:", bst.maximum().data)
    assert bst.maximum().data == 17

    print("9. Successor of 13:", bst.successor(13).data)
    assert bst.successor(13).data == 15

    print("10. Remove 10 (root)")
    bst.remove(10)

    try:
        assert bst.search(10).is_empty()
        print("True")
    except AssertionError as e:
      print(e)

test_bst()
# Out:
# 1. In-Order Traversal: [1, 3, 4, 5, 6, 7, 10, 13, 15, 17]
# 2. Pre-Order Traversal: [10, 5, 3, 1, 4, 7, 6, 15, 13, 17]
# 3. Post-Order Traversal: [1, 4, 3, 6, 7, 5, 13, 17, 15, 10]
# 4. Height: 3
# 5. Size: 10
# 6. Search 13: 13
# 7. Minimum: 1
# 8. Maximum: 17
# 9. Successor of 13: 15
# 10. Remove 10 (root)
# True

# %% [markdown]
# # Exercícios

# %%
# @title {vertical-output: true}

# EXERCÍCIO 01

# Considere a implementação de uma BST recursiva.
# Implemente um método que soma a quantidade de nós menores
# que a raiz da estrutura.

# Escreva seu código abaixo:

# %%
# @title {vertical-output: true}

# EXERCÍCIO 02

# Considere a implementação de uma BST recursiva.
# Implemente um método que soma a quantidade de nós maiores
# que a raiz da estrutura.

# Escreva seu código abaixo:

# %%
# @title {vertical-output: true}

# EXERCÍCIO 03

# Considere a implementação de uma BST recursiva.
# Implemente um método que imprime os valores da estrutura
# em ordem decrescente.

# Escreva seu código abaixo:

# %%
# @title {vertical-output: true}

# EXERCÍCIO 04

# Considere a implementação de uma BST recursiva.
# Implemente um método que imprime os valores da estrutura
# em ordem crescente.

# Escreva seu código abaixo:

# %%
# @title {vertical-output: true}

# EXERCÍCIO 05

# Considere a implementação de uma BST recursiva.
# Implemente um método que diz se uma árvore é idêntica a outra.
# Para tanto, ela precisa ter a mesma estrutura e os mesmos
# valores.

# Escreva seu código abaixo:

# %%
# @title {vertical-output: true}

# EXERCÍCIO 06

# Considere a implementação de uma BST recursiva.
# Implemente um método que remove ambos o menor e o maior
# valores da estrutura.

# Escreva seu código abaixo:

# %% [markdown]
# `Rafael de Arruda Sobral, 2025. Estruturas de Dados e Algoritmos (Monitoria), UFCG.`
#
# `Prof. Dr. Adalberto Cajueiro de Farias, 2025. Estruturas de Dados e Algoritmos, UFCG.`
